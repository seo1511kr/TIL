# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
gender=pd.read_csv('gender_submission.csv')
test=pd.read_csv('test.csv')
train=pd.read_csv('train.csv')

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
for i in train.columns:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %% [markdown]
# PassengerId
# Survived:생존여부
# Pclass:티켓등급
# Name:이름
# Sex:성별
# Age:나이
# SibSp:같이 탑승한 형제 배우자
# Parch: 같이 탑승한 부모자식
# Ticket:티켓넘버
# Fare:요금
# Cabin:선실 번호
# Embarked:탑승항구
#
# model: pclass별 평균 fare가 있는데 그걸 크게 벗어나서 싸게 산 사람들은 기회주의자들일 가능성이 있음.
# 기회주의자들은  살 기회를 놓치지 않는 경향이 있을듯함. 생존력이 높아보임
#
#
# 가족 혹은 연인단위 방문객 중 여성, 아동의 생존률을 살펴보자 유의미 한 차이가 있을듯 함
#
# 타이타닉 배는 가족단위 이외에는 남자와 여자를 따로 태웠다고 함
#
# 선실 번호로 각 선실의 층을 알 수가 있음
# 1등실 사이에도 클래스 차이가 존재할 것
# 최상급 클래스들의 선실 생존자들의 생존률을 살펴보자 최상위 클래스들은 살았을 확률이 높아보임

# %%
종속변수가 범주형일때
    로지스틱 회귀-오즈 오즈비 로그오즈비(독립변수는 연속형일때 )
    분산분석- 독립변수도 범주형일때

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
