# %%
import urllib
import json
from pprint import pprint 
from pandas.io.json import json_normalize

# %%
# xml만 제공해서 xml로 받은 후  json으로 파싱하기

keys='504a75527073656f31323379654d557a'
url1="http://openapi.seoul.go.kr:8088/"+keys+"/xml/SpotInfo/1/1000/"

# %%
request = urllib.request.Request(url1)
response = urllib.request.urlopen(request)
response_body = response.read().decode('utf-8')

# %%
print(response_body)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><SpotInfo><list_total_count>169</list_total_count><RESULT><CODE>INFO-000</CODE><MESSAGE>정상 처리되었습니다</MESSAGE></RESULT><row><spot_num>A-01</spot_num><spot_nm>성산로(금화터널)</spot_nm><grs80tm_x>195489</grs80tm_x><grs80tm_y>452136</grs80tm_y></row><row><spot_num>A-02</spot_num><spot_nm>사직로(사직터널)</spot_nm><grs80tm_x>196756.776106</grs80tm_x><grs80tm_y>452546.638644</grs80tm_y></row><row><spot_num>A-03</spot_num><spot_nm>자하문로(자하문터널)</spot_nm><grs80tm_x>197216.855046</grs80tm_x><grs80tm_y>454350.990432</grs80tm_y></row><row><spot_num>A-04</spot_num><spot_nm>대사관로(삼청터널)</spot_nm><grs80tm_x>198648.893154</grs80tm_x><grs80tm_y>455200.108465</grs80tm_y></row><row><spot_num>A-05</spot_num><spot_nm>율곡로(안국역)</spot_nm><grs80tm_x>198645.671347</grs80tm_x><grs80tm_y>452937.216603</grs80tm_y></row><row><spot_num>A-06</spot_num><spot_nm>창경궁로(서울여자대학교)</spot_nm><grs80tm_x>199825.89671</grs80tm_x><grs80tm_y>453668.322568</grs80tm_y></row><row><spot_num>A-07
# ...

# %%
# xml => json

import xmltodict

#먼저 orderdict로 변환
OrderDict=xmltodict.parse(response_body)
#이후 json 문자열로
jsonString= json.dumps(OrderDict,indent=4)

# %%
# json으로 변환
json_obj=json.loads(jsonString)
json_obj
# Out:
# {'SpotInfo': {'list_total_count': '169',
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'spot_num': 'A-01',
#     'spot_nm': '성산로(금화터널)',
#     'grs80tm_x': '195489',
#     'grs80tm_y': '452136'},
#    {'spot_num': 'A-02',
#     'spot_nm': '사직로(사직터널)',
#     'grs80tm_x': '196756.776106',
#     'grs80tm_y': '452546.638644'},
#    {'spot_num': 'A-03',
#     'spot_nm': '자하문로(자하문터널)',
#     'grs80tm_x': '197216.855046',
#     'grs80tm_y': '454350.990432'},
#    {'spot_num': 'A-04',
#     'spot_nm': '대사관로(삼청터널)',
#     'grs80tm_x': '198648.893154',
#     'grs80tm_y': '455200.108465'},
#    {'spot_num': 'A-05',
#     'spot_nm': '율곡로(안국역)',
#     'grs80tm_x': '198645.671347',
#     'grs80tm_y': '452937.216603'},
#    {'spot_num': 'A-06',
#     'spot_nm': '창경궁로(서울여자대학교)',
#     'grs80tm_x': '199825.89671',
#     'grs80tm_y': '453668.322568'},
#    {'spot_num': 'A-07',
#     'spot_nm': '대학로(한국방송통신대학교)',
#     'grs80tm_x': '200185.014636',
# ...

# %%
# json => dataframe
from pandas.io.json import json_normalize 
df=pd.json_normalize(json_obj['SpotInfo']['row'])

# %%
df.head(5)
# Out:
#   spot_num      spot_nm      grs80tm_x      grs80tm_y
# 0     A-01    성산로(금화터널)         195489         452136
# 1     A-02    사직로(사직터널)  196756.776106  452546.638644
# 2     A-03  자하문로(자하문터널)  197216.855046  454350.990432
# 3     A-04   대사관로(삼청터널)  198648.893154  455200.108465
# 4     A-05     율곡로(안국역)  198645.671347  452937.216603

# %%
df.to_csv('서울도로정보.csv')

# %%
import pandas as pd

# %% [markdown]
# # 서울 대기오염물질 배출시설현황

# %%
positions=pd.read_excel("C:/Users/19178/Desktop/suwoon/대기오염측정소 위치정보/서울측정소.xls")

# %%
positions.head()
# Out:
#   Unnamed: 0 Unnamed: 1                    Unnamed: 2    Unnamed: 3 Unnamed: 4
# 0    측정소 리스트        NaN                           NaN           NaN        NaN
# 1        NaN        NaN                           NaN           NaN        NaN
# 2        지역명       측정소명                        측정소 주소          운영기관       설치년도
# 3         서울        강남구     서울 강남구 학동로 426 강남구청 별관 1동  서울특별시보건환경연구원       1978
# 4         서울        강동구  서울 강동구 구천면로 42길 59 천호1동 주민센터  서울특별시보건환경연구원       1997

# %%
len(positions)
# Out:
# 28

# %%
positions.loc[3:29,]
# Out:
#    Unnamed: 0 Unnamed: 1                                     Unnamed: 2  \
# 3          서울        강남구                      서울 강남구 학동로 426 강남구청 별관 1동
# 4          서울        강동구                   서울 강동구 구천면로 42길 59 천호1동 주민센터
# 5          서울        강북구                    서울 강북구 삼양로 139길 49 우이동 주민센터
# 6          서울        강서구             서울 강서구 강서로 45 다길 71 화곡3동 푸른들청소년도서관
# 7          서울        관악구                        서울 관악구 신림동길 14 신림동 주민센터
# 8          서울        광진구                  서울특별시 광진구 광나루로 571 구의 아리수정수센터
# 9          서울        구로구                      서울 구로구 가마산로 27길 45 구로고등학교
# 10         서울        금천구                     서울 금천구 금하로21길 20 시흥5동 주민센터
# 11         서울        노원구  서울 노원구 상계로 118 상계2동 주민센터 (23길 17 노원구 원터행복발전소)
# 12         서울        도봉구                    서울 도봉구 시루봉로2길 34 쌍문동청소년문화의집
# 13         서울       동대문구                      서울 동대문구 천호대로13길 43 용두초등학교
# 14         서울        동작구                     서울 동작구 사당로16아길 6 사당4동 주민센터
# ...

# %%
seoul=pd.read_csv("C:/Users/19178/Desktop/suwoon/대기오염현황2020/서울시 일별 평균 대기오염도 정보.csv",
                 encoding='cp949')

# %%
seoul.head(5)
# Out:
#        측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0  20210309   강남구         0.041      0.019           0.6       0.004
# 1  20210309  강남대로         0.046      0.013           0.9       0.003
# 2  20210309   강동구         0.041      0.019           0.6       0.003
# 3  20210309  강변북로         0.046      0.013           0.7       0.003
# 4  20210309   강북구         0.026      0.023           0.5       0.003
#
#    미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0       45.0        31.0
# 1       52.0        30.0
# 2       51.0        32.0
# 3       56.0        32.0
# 4       42.0        24.0

# %%
import re

# %%
seoul.측정소명
# Out:
# 0         강남구
# 1        강남대로
# 2         강동구
# 3        강변북로
# 4         강북구
#          ...
# 17745    청계천로
# 17746    한강대로
# 17747      행주
# 17748     홍릉로
# 17749     화랑로
# Name: 측정소명, Length: 17750, dtype: object

# %%
re.match()
