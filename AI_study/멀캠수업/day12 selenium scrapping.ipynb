# %% [markdown]
# # 다나와 무선청소기 scrapping
#
# ### 드라이버가 url 로딩하는 시간을 기다려줘야함

# %% [markdown]
# ## 파이참과 별도로 selenium 설치해야함
#
# ### 시작 > 아나콘다 prompt > pip install selenium

# %%
from selenium import webdriver
driver=webdriver.Chrome('c:/scrap/chromedriver.exe')
url="http://search.danawa.com/dsearch.php?query=무선청소기&tab=main"

# %%
driver.get(url)

# %%
from bs4 import BeautifulSoup
html=driver.page_source
soup=BeautifulSoup(html, "html.parser")

prod_item=soup.select("li.prod_item")
print(prod_item[1])
print("="*50)
print(len(prod_item))
# Out:
# <li class="prod_item" id="productItem9781572">
# <input id="productItem_categoryInfo_9781572" type="hidden" value="생활가전_청소기"/>
# <input id="min_price_9781572" type="hidden" value="147160"/>
# <div class="prod_main_info">
# <div class="thumb_image">
# <a class="thumb_link" href="http://prod.danawa.com/info/?pcode=9781572&amp;keyword=무선청소기&amp;cate=103740" id="thumbLink_9781572" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
# <img alt="V10" class="click_log_product_standard_img_" src="http://img.danawa.com/prod_img/500000/572/781/img/9781572_1.jpg?shrink=160:160&amp;_v=20210110210436"/>
# </a>
# <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_9781572" onclick="return false;">
# <span class="ico i_zoom_vw"></span>이미지보기
# 							</a>
# <input id="hidden_cate_sub_c1" type="hidden" value="72"/>
# <input id="hidden_cate_sub_c2" type="hidden" value="80"/>
# <input id="hidden_cate_sub_c3" type="hidden" value="81"/>
# </div>
# ...

# %%
prod_item[1]
# Out:
# <li class="prod_item" id="productItem9781572">
# <input id="productItem_categoryInfo_9781572" type="hidden" value="생활가전_청소기"/>
# <input id="min_price_9781572" type="hidden" value="147160"/>
# <div class="prod_main_info">
# <div class="thumb_image">
# <a class="thumb_link" href="http://prod.danawa.com/info/?pcode=9781572&amp;keyword=무선청소기&amp;cate=103740" id="thumbLink_9781572" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
# <img alt="V10" class="click_log_product_standard_img_" src="http://img.danawa.com/prod_img/500000/572/781/img/9781572_1.jpg?shrink=160:160&amp;_v=20210110210436"/>
# </a>
# <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_9781572" onclick="return false;">
# <span class="ico i_zoom_vw"></span>이미지보기
# 							</a>
# <input id="hidden_cate_sub_c1" type="hidden" value="72"/>
# <input id="hidden_cate_sub_c2" type="hidden" value="80"/>
# <input id="hidden_cate_sub_c3" type="hidden" value="81"/>
# </div>
# ...

# %%
prod_item=soup.select("li.prod_item")
print(len(prod_item))
name_list=[]
for i in range(len(prod_item)):
    info=prod_item[i].select("div.prod_info")
    name=info[0].select("a")[0].string
    name_list.append(name)
print(name_list)
# Out:
# 42
# ['라이프로 RX10', '샤오미 드리미 V10', 'LG전자 코드제로 ThinQ A9S A9700', '삼성전자 제트 VS15R8500BF', None, 'LG전자 코드제로 ThinQ A9S A9570', 'ko3g6ZgFNa', 'LG전자 코드제로 A9 A9100', '샤오미 드리미 V11', '다이슨 V8 플러피', '삼성전자 제트 VS20T9258SDCS', '일렉트로룩스 WELL Q6 WQ61-1OGG', '다이슨 디지털 슬림 플러피+', '삼성전자 제트 VS20T9257SECS', '다이슨 V10 카본파이버', '삼성전자 제트 VS20T9213QDCSP', '다이슨 옴니 글라이드 컴플리트+', '다이슨 V11 컴플리트', 'LG전자 코드제로 ThinQ A9S A9470', '삼성전자 제트 VS20T9213QDCSW', '다이슨 옴니 글라이드+', '휴스톰 HS-10000', 'LG전자 코드제로 ThinQ A9S A9500', 'LG전자 코드제로 A9S A9300', '샤오미 SHUNZAO Z11', 'DIBEA TSX-25000A', None, '삼성전자 VC-H22', '일렉트로룩스 WELL Q7 WQ71-2OIB', '일렉트로룩스 PURE Q9 PQ92-3OBF', 'LG전자 코드제로 ThinQ A9S A9400', '삼성전자 제트 VS20R9078S2', '샤오미 드리미 V9', '일렉트로룩스 라피도 ZB6114', '삼성전자 제트 VS15R8543S1CW', 'LG전자 코드제로 A9S A9370', '샤오미 TROUVER TECH SOLO10', '일렉트로룩스 에르고라피도 ZB3311', '샤오미 SWDK-D260', '한샘 HSBC-6000W', '일렉트로룩스 WELL Q7 WQ71-2BSWF', '다이슨 V8 카본파이버']

# %%
# 2) 인치

spec_list=list(range(0,len(prod_item)))
for i in range(len(prod_item)):
    info=prod_item[i].select("div.prod_info")
    spec=info[0].select("div.spec_list > a")
    spec_list[i]=[]
    for j in spec:
        spec_list[i].append(j.string)
print(spec_list)
# Out:
# [['로봇청소기', '흡입+걸레', '전압', '14.4V', '헤파필터', 'H14급', 'BLDC모터', '흡입력', '3000Pa', '먼지통용량', '0.475L', '물통용량', '0.22L', '사용시간', '3시간', '배터리', '리튬이온', '용량', '5200mAh', 'LDS센서', '추락방지센서', '범핑센서', '청소모드', '지정영역청소', '간편업데이트', '금지구역', '원격예약', '원격청소', '이동동선확인', '스마트맵핑', '바닥마스터', '자동충전', '음성안내', '리모콘', '소비전력', '30W', '색상:퓨어화이트, 매트블랙'], [None, '핸디+스틱형', '무선형', '전압', '25.2V', '헤파필터', 'H12급', '5단계여과', '흡입력', '140AW', '흡입력', '22000Pa', '먼지통용량', '0.5L', '충전시간', '3시간30분', '사용시간', '1시간', '용량', '2500mAh', '바닥', '침구', '솔형', '틈새', '연장툴', '거치대', '무게', '1.5kg', '색상:화이트', '소비전력', '450W'], [None, '핸디+스틱형', '무선형', '헤파필터', '2중터보싸이클론', '5단계여과', '인버터모터', '흡입력', '200W', '충전시간', '4시간', '사용시간', '2시간', '배터리', '리튬이온 (2개)', '바닥', '물걸레', '침구', '솔형', '굳은먼지', '상부청소', '틈새', '긴틈새', '매트리스', '연장툴', '거치대', '자동물공급', '디스플레이표시창', '배터리잔량표시', 'WiFi', '색상:판타지실버', '소비전력', '590W', '미세먼지인증(SLG)'], [None, '핸디+스틱형', '무선형', '전압', '21.6V', '헤파필터', '싸이클론', '5단계여과', '인버터모터', '흡입력', '150W', '먼지통용량', '0.5L', '충전시간', '3시간30분', '사용시간', '40분', '배터
# ...

# %%
spec_list=list(range(0,len(prod_item)))
spec=prod_items[0].select("div.spec_list > a")
print(spec)
print(len(spec))
for i in spec:
    print(i.string)
# Out:
# [<a class="view_dic" href="#" onclick="$.termDicViewLink(3994,'view',this,0,72,80); return false;">로봇청소기</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(7157,'view',this,0,72,80); return false;">흡입+걸레</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(213565,'view',this,0,72,80); return false;">전압</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(213565,'view',this,0,72,80); return false;">14.4V</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(14801,'view',this,0,72,80); return false;">헤파필터</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(14801,'view',this,0,72,80); return false;">H14급</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(31525,'view',this,0,72,80); return false;">BLDC모터</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">흡입력</a>, <a class="view_dic" href="#" onclick="$.termDicViewLink(3996,'view',this,0,72,80); return false;">3000Pa</a>, <a class="view
# ...

# %%
prod_data = []
for prod_item in prod_items:
    try: 
        title = prod_item.select('p.prod_name > a')[0].text.strip()
    except:
        title = ''
    try: 
        spec_list = prod_item.select('div.spec_list')[0].text.strip()
    except:
        spec_list = ''
    try: 
        price = prod_item.select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(",","")
    except:
        price = 0
    prod_data.append([title, spec_list, price])
    
print(len(prod_data))
print(prod_data)
# Out:
# 42
# ...

# %%
# 3) 등록월====오류====================================
import re
Date_list=list(range(0,len(prod_item)))
for i in range(len(prod_item)):
    Date=prod_item[i].select("div.prod_info > div.prod_sub_info > div > dl.meta_item.mt_date > dd")
    print(Date)
# Out:
# [<dd>2020.10</dd>]
# [<dd>2019.10</dd>]
# [<dd>2020.03</dd>]
# [<dd>2020.10</dd>]
# [<dd>2020.02</dd>]
# [<dd>2020.04</dd>]
# []
# [<dd>2020.11</dd>]
# [<dd>2020.06</dd>]
# [<dd>2019.05</dd>]
# [<dd>2020.09</dd>]
# [<dd>2020.09</dd>]
# [<dd>2020.07</dd>]
# [<dd>2020.09</dd>]
# [<dd>2018.09</dd>]
# [<dd>2020.12</dd>]
# [<dd>2020.10</dd>]
# [<dd>2019.04</dd>]
# [<dd>2020.05</dd>]
# [<dd>2020.10</dd>]
# [<dd>2020.10</dd>]
# [<dd>2019.03</dd>]
# [<dd>2020.05</dd>]
# [<dd>2020.05</dd>]
# [<dd>2020.01</dd>]
# [<dd>2019.12</dd>]
# [<dd>2019.10</dd>]
# [<dd>2018.07</dd>]
# [<dd>2020.09</dd>]
# [<dd>2020.05</dd>]
# [<dd>2020.05</dd>]
# [<dd>2019.02</dd>]
# [<dd>2019.02</dd>]
# [<dd>2017.05</dd>]
# [<dd>2020.03</dd>]
# [<dd>2020.06</dd>]
# [<dd>2020.11</dd>]
# [<dd>2017.09</dd>]
# [<dd>2017.08</dd>]
# [<dd>2020.05</dd>]
# [<dd>2020.09</dd>]
# [<dd>2017.09</dd>]

# %%
# 4) 평점, 평점을 매긴 건수
point_list=[]
for i in range(len(prod_item)):
    point=prod_item[i].select("div.prod_info > div.prod_sub_info > div > dl.meta_item.mt_comment > dd > div.cnt_star > div.point_num > strong")
    print(point)
    point_list.append(point.string)
print(point_list)
evalnum_list=[]
for i in range(len(prod_item)):
    evalnum=prod_item[i].select("div.prod_info > div.prod_sub_info > div > dl.meta_item.mt_comment > dd > div.cnt_opinion > a > strong")
    evalnum_list.append(evalnum.string)
print(evalnum_list)#===============================================

# %%
prod_items = soup.select('ul.product_list > li.prod_item')
len(prod_items)
# Out:
# 42

# %%
prod_item[0].select("p.prod_name > a")
# Out:
# [<a href="http://prod.danawa.com/info/?pcode=12583850&amp;keyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&amp;cate=103744" onmousedown="_trkEventLog('통합검색_광고상품_라이프로 RX10');" target="_blank">라이프로 RX10</a>]

# %%
prod_item[0].select("p.prod_name > a")[0].string
# Out:
# '라이프로 RX10'

# %%
prod_item[0].select("p.prod_name > a")[0].text
# Out:
# '라이프로 RX10'

# %% [markdown]
# # 스타벅스 매장 지도정보 스크래핑
# https://www.istarbucks.co.kr/store/store_map.do?disp=locale

# %% [markdown]
# ## 1. 스타벅스 주소 접속

# %%
from selenium import webdriver
browser=webdriver.Chrome('c:/scrap/chromedriver.exe')
url="https://www.istarbucks.co.kr/store/store_map.do?disp=locale"

# %%
browser.get(url)

# %% [markdown]
# ## 2. 버튼 클릭을 프로그램이 직접 하도록

# %%
seoulBtn="#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a"
# gyeongiBtn="#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(2) > a"
# Out:
# [<ul class="sido_arae_box">
# </ul>]

# %% [markdown]
# # 버튼 매크로 만들기(성공)
# ## mCSB_2_container > ul > li:nth-child(1) > a (버튼경로)
#
#
# # 실패했던 이유
#
# ## for 문 안에 url, browser.get(url)을 넣어줘야
# ## 리스트 출력후 다시 초기화해서 처음 화면으로 돌아감!!

# %%
import time

from selenium import webdriver
browser=webdriver.Chrome('c:/scrap/chromedriver.exe')
korea_sb_litst=[]

for i in range(1,17):
    url="https://www.istarbucks.co.kr/store/store_map.do?disp=locale"
    browser.get(url)
    time.sleep(2)
    browser.find_element_by_css_selector("#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(%d) > a"%i).click()
    time.sleep(2)
    allBtn="#mCSB_2_container > ul > li:nth-child(1) > a"
    browser.find_element_by_css_selector(allBtn).click()
    time.sleep(2)
    html=browser.page_source
    soup=BeautifulSoup(html,"html.parser")
    sb_list=soup.select("li.quickResultLstCon")
    for item in sb_list:
        name=item.select("strong")[0].text
        sb_store=sb_list[0]
        lat=item['data-lat']
        lng=item['data-long']
        tel=str(item.select("p.result_details")[0]).split("<br/>")[1].split("<")[0]
        addr=str(item.select("p.result_details")[0]).split("<br/>")[0].split(">")[1]
        sb_type=item.select("i")[0]['class'][0][4:]
        korea_sb_litst.append([name,lat,lng,sb_type,addr,tel])
    print(korea_sb_litst)
# Out:
# [['역삼아레나빌딩  ', '37.501087', '127.043069', 'general', '서울특별시 강남구 언주로 425 (역삼동)', '1522-3232'], ['논현역사거리  ', '37.510178', '127.022223', 'general', '서울특별시 강남구 강남대로 538 (논현동)', '1522-3232'], ['신사역성일빌딩  ', '37.514132', '127.020563', 'general', '서울특별시 강남구 강남대로 584 (논현동)', '1522-3232'], ['국기원사거리  ', '37.499517', '127.031495', 'general', '서울특별시 강남구 테헤란로 125 (역삼동)', '1522-3232'], ['스탈릿대치R  ', '37.494668', '127.062583', 'reserve', '서울특별시 강남구 남부순환로 2947 (대치동)', '1522-3232'], ['봉은사역  ', '37.515000', '127.063196', 'general', '서울특별시 강남구 봉은사로 619 (삼성동)', '1522-3232'], ['압구정윤성빌딩  ', '37.5227934', '127.0286009', 'general', '서울특별시 강남구 논현로 834 (신사동)', '1522-3232'], ['코엑스별마당  ', '37.510150', '127.060275', 'general', '서울특별시 강남구 영동대로 513 (삼성동)', '1522-3232'], ['삼성역섬유센터R  ', '37.507750', '127.060651', 'reserve', '서울특별시 강남구 테헤란로 518 (대치동)', '1522-3232'], ['압구정R  ', '37.5273669', '127.033061', 'reserve', '서울특별시 강남구 언주로 861 (신사동)', '1522-3232'], ['수서역R  ', '37.488008', '127.102650', 'reserve', '서울특별시 강남구 광평로 
# ...

# %%
browser.find_element_by_css_selector(seoulBtn).click()

# %%
allBtn="#mCSB_2_container > ul > li:nth-child(1) > a"

# %%
browser.find_element_by_css_selector(allBtn).click()

# %%
html=browser.page_source
soup=BeautifulSoup(html,"html.parser")

# %%
print(soup)
# Out:
# <html lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="website" property="og:type"/>
# <meta content="Starbucks" property="og:title"/>
# <meta content="https://www.starbucks.co.kr/" property="og:url"/>
# <meta content="https://image.istarbucks.co.kr/common/img/kakaotalk.png" property="og:image"/>
# <meta content="Starbucks" property="og:description"/>
# <title id="titleJoin">Starbucks Coffee Korea</title>
# <link href="https://image.istarbucks.co.kr/common/img/common/favicon.ico?v=200828" rel="shortcut icon" type="image/ico"/> <!-- 20200827 파비콘 교체 및 CDN 변수처리 -->
# <link href="/common/css/reset.css" rel="stylesheet"/>
# <link href="/common/css/style.css?v=200130" rel="stylesheet"/>
# <link href="/common/css/jquery.bxslider.css" rel="stylesheet"/>
# ...

# %%
sb_list=soup.select("li.quickResultLstCon")
print(len(sb_list))
# Out:
# 533

# %%
sb_store=sb_list[0]
print(sb_store)
print("="*50)
name=sb_store.select("strong")[0].text
print(sb_list[0].select("strong")[0].text)
# string은 내부에 태그나 string 이외의 것이 있으면  None으로 출력함
print(sb_store['data-lat']) #attribute(속성)활용하여 위도정보 추출
lat=sb_store['data-lat']
lng=sb_store['data-long']
print(lng)
print(sb_store.select("i")[0]['class'][0][4:]) #매장 타입
sb_type=sb_store.select("i")[0]['class'][0]
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong>역삼아레나빌딩  <img alt="" class="setStoreFavBtn mCS_img_loaded" data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N" src="//image.istarbucks.co.kr/common/img/store/icon_fav_off.png"/></strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>
# ...
# 역삼아레나빌딩
# 37.501087
# 127.043069
# general

# %% [markdown]
# ### br태그 무시하고 주소와 전화번호 따로 뽑기
# ### 1. text를 사용하면 br태그 무시됨
# ### 2. string으로 하면 br태그가 포함되어 None으로 출력함
# ### 3. str()로 묶고 .split("<br/>") 로 나눠도 됨

# %%
print(sb_store.select("p.result_details"))
# Out:
# [<p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p>]

# %% [markdown]
# ### .text로 하기

# %%
sb_store.select("p.result_details")[0].text
# Out:
# None

# %%
len(sb_store.select("p.result_details")[0].text)
# Out:
# 32

# %%
addr=sb_store.select("p.result_details")[0].text[:-9]
tel=sb_store.select("p.result_details")[0].text[-9:]
print(addr,tel)
# Out:
# 서울특별시 강남구 언주로 425 (역삼동) 1522-3232

# %% [markdown]
# ### str() 과 .split으로 하기

# %%
print(str(sb_store.select("p.result_details")[0]))
# Out:
# <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p>

# %%
print(str(sb_store.select("p.result_details")[0]).split("<br/>"))
# Out:
# ['<p class="result_details">서울특별시 강남구 언주로 425 (역삼동)', '1522-3232</p>']

# %%
print(str(sb_store.select("p.result_details")[0]).split("<br/>")[0].split(">")[1])
# Out:
# 서울특별시 강남구 언주로 425 (역삼동)

# %%
print(str(sb_store.select("p.result_details")[0]).split("<br/>")[1].split("<")[0])
# Out:
# 1522-3232

# %% [markdown]
# ## 서울시 전체에 대해서 for문 만들기

# %%
for item in sb_list:
    print(item)
    print("="*50)
print(len(sb_list))
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong>역삼아레나빌딩  <img alt="" class="setStoreFavBtn mCS_img_loaded" data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N" src="//image.istarbucks.co.kr/common/img/store/icon_fav_off.png"/></strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>
# ...

# %%
seoul_sb_litst=[]
for item in sb_list:
    name=item.select("strong")[0].text
    sb_store=sb_list[0]
    lat=item['data-lat']
    lng=item['data-long']
    tel=str(item.select("p.result_details")[0]).split("<br/>")[1].split("<")[0]
    addr=str(item.select("p.result_details")[0]).split("<br/>")[0].split(">")[1]
    sb_type=item.select("i")[0]['class'][0][4:]
    seoul_sb_litst.append([name,lat,lng,sb_type,addr,tel])
print(seoul_sb_litst)
# Out:
# [['역삼아레나빌딩  ', '37.501087', '127.043069', 'general', '서울특별시 강남구 언주로 425 (역삼동)', '1522-3232'], ['논현역사거리  ', '37.510178', '127.022223', 'general', '서울특별시 강남구 강남대로 538 (논현동)', '1522-3232'], ['신사역성일빌딩  ', '37.514132', '127.020563', 'general', '서울특별시 강남구 강남대로 584 (논현동)', '1522-3232'], ['국기원사거리  ', '37.499517', '127.031495', 'general', '서울특별시 강남구 테헤란로 125 (역삼동)', '1522-3232'], ['스탈릿대치R  ', '37.494668', '127.062583', 'reserve', '서울특별시 강남구 남부순환로 2947 (대치동)', '1522-3232'], ['봉은사역  ', '37.515000', '127.063196', 'general', '서울특별시 강남구 봉은사로 619 (삼성동)', '1522-3232'], ['압구정윤성빌딩  ', '37.5227934', '127.0286009', 'general', '서울특별시 강남구 논현로 834 (신사동)', '1522-3232'], ['코엑스별마당  ', '37.510150', '127.060275', 'general', '서울특별시 강남구 영동대로 513 (삼성동)', '1522-3232'], ['삼성역섬유센터R  ', '37.507750', '127.060651', 'reserve', '서울특별시 강남구 테헤란로 518 (대치동)', '1522-3232'], ['압구정R  ', '37.5273669', '127.033061', 'reserve', '서울특별시 강남구 언주로 861 (신사동)', '1522-3232'], ['수서역R  ', '37.488008', '127.102650', 'reserve', '서울특별시 강남구 광평로 
# ...

# %%
import pandas as pd

# %%
col=['매장명','위도','경도','매장타입','주소','전화번호']

# %%
sd_df=pd.DataFrame(seoul_sb_litst, columns=col)
print(sd_df)
# Out:
#            매장명                 위도                  경도     매장타입  \
# 0    역삼아레나빌딩            37.501087          127.043069  general
# 1     논현역사거리            37.510178          127.022223  general
# 2    신사역성일빌딩            37.514132          127.020563  general
# 3     국기원사거리            37.499517          127.031495  general
# 4     스탈릿대치R            37.494668          127.062583  reserve
# ..         ...                ...                 ...      ...
# 528     사가정역            37.579594          127.087966  general
# 529      상봉역             37.59689           127.08647  general
# 530    묵동이마트            37.613433          127.077484  general
# 531       묵동            37.615368          127.076633  general
# 532      중화역    37.60170912407773  127.07841136432036  general
#
#                                     주소       전화번호
# 0              서울특별시 강남구 언주로 425 (역삼동)  1522-3232
# 1             서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# 2             서울특별시 강남구 강남대로 584 (논현동)  1522-3232
# ...

# %%
sd_df.head()
# Out:
#          매장명         위도          경도     매장타입                          주소  \
# 0  역삼아레나빌딩    37.501087  127.043069  general     서울특별시 강남구 언주로 425 (역삼동)
# 1   논현역사거리    37.510178  127.022223  general    서울특별시 강남구 강남대로 538 (논현동)
# 2  신사역성일빌딩    37.514132  127.020563  general    서울특별시 강남구 강남대로 584 (논현동)
# 3   국기원사거리    37.499517  127.031495  general    서울특별시 강남구 테헤란로 125 (역삼동)
# 4   스탈릿대치R    37.494668  127.062583  reserve  서울특별시 강남구 남부순환로 2947 (대치동)
#
#         전화번호
# 0  1522-3232
# 1  1522-3232
# 2  1522-3232
# 3  1522-3232
# 4  1522-3232

# %%
sd_df.to_excel("스터벅스목록.xlsx",index=False)

# %% [markdown]
# # 인스타그램 스크래핑

# %% [raw]
# ## 게시물 하나의 스크래핑만 만든 후 for loop 만들기

# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome("c:/scrap/chromedriver.exe")

# %%
import time
url="https://www.instagram.com/"
driver.get(url)
time.sleep(2) #2초동안 대기 로딩시간

# %% [markdown]
# #### 공격자 오류 chrombrowser settings 고급 설정을 기본값으로 복원

# %% [markdown]
# ## 로그인

# %%
email="horang295"
input_id=driver.find_element_by_css_selector("#loginForm > div > div:nth-child(1) > div > label > input")
input_id.clear()
input_id.send_keys(email)


password="dbsgh%464"
input_pw=driver.find_element_by_css_selector("#loginForm > div > div:nth-child(2) > div > label > input")
input_pw.clear()
input_pw.send_keys(password)
input_pw.submit()
time.sleep(3)

# %% [markdown]
# ## 검색

# %%
def insta_searching(word):
    url="https://www.instagram.com/explore/tags/"+word
    return url

# %%
word="제주도맛집"
url=insta_searching(word)
driver.get(url)

# %% [markdown]
# ##  첫번째 항목 클릭

# %%
def select_first(driver):
    first=driver.find_element_by_css_selector("div._9AhH0")
    first.click()
    time.sleep(3)

# %%
select_first(driver)

# %% [markdown]
# # contents scrapping

# %%
def getContent(driver):
    #스크래핑
    html=driver.page_source
    soup=BeautifulSoup(html,"html.parser")
    content=soup.select("div.C4VMK")[0].text
    tag=re.findall("#[^\s,]+",soup.select("div.C4VMK")[0].text)[0] #해쉬태그
    day=soup.select("time._1o9PC.Nzb55")[0]["title"]
    time=soup.select("time._1o9PC.Nzb55")[0].text#time
    return [content,tag,day,time]

# %%
# getContent(driver)
# 전체 컨테이너 주소:"body > div._2dDPU.CkGkG > div.zZYga > div > article > div.eo2As > div.EtaWk > ul > div > li > div > div > div.C4VMK"
# 본문 내용:"body > div._2dDPU.CkGkG > div.zZYga > div > article > div.eo2As > div.EtaWk > ul > div > li > div > div > div.C4VMK > span"

# %%
import re
print(type(getContent(driver)))
# Out:
# <class 'list'>

# %%
getContent(driver)
# Out:
# ['sandorong5659산도롱맨도롱----------🍜제주 유일무이 고기국수 맛집🍜갈비국수 한입, 바다 한입🤭뷰까지 완벽한 산도롱맨도롱에서사골육수 100% 진하게 우려낸속 까지 깊은 맛을 경험해보세요 :)  ..산도롱맨도롱동절기영업시간:08:00~20:00(last 19:00)문의 : 064-782-5105.#제주도맛집#제주맛집#제주도고기국수#성산일출봉맛집#광치기해변맛집#제주돔베고기#성산일출봉고기국수맛집#제주도점심#성산아침식사#성산일출봉아침식사2시간',
#  '#제주도맛집#제주맛집#제주도고기국수#성산일출봉맛집#광치기해변맛집#제주돔베고기#성산일출봉고기국수맛집#제주도점심#성산아침식사#성산일출봉아침식사2시간',
#  '2021년 1월 15일',
#  '2시간 전']

# %% [markdown]
# ## 다음페이지 이동

# %%
next=driver.find_element_by_css_selector("body > div._2dDPU.CkGkG > div.EfHg9 > div > div > a")
next.click()

# %% [markdown]
# ###  좋아요 매크로
